# %% [markdown]
# # YOLO Basics
#
# Ultralytics YOLO를 사용한 Object Detection 기초 학습

# %%
import sys
sys.path.insert(0, '../../src')

from ultralytics import YOLO
from cv_pkg.utils import draw_bbox, show_images, load_image

# %% [markdown]
# ## 1. 모델 로드

# %%
# YOLOv8n (nano) 모델 로드
model = YOLO('yolov8n.pt')

# %% [markdown]
# ## 2. 추론 (Inference)

# %%
# 이미지에서 객체 탐지
# results = model('path/to/image.jpg')
# results[0].show()

# %% [markdown]
# ## 3. 결과 분석

# %%
# 탐지 결과 확인
# boxes = results[0].boxes
# print(f"탐지된 객체 수: {len(boxes)}")
# print(f"클래스: {boxes.cls}")
# print(f"신뢰도: {boxes.conf}")
# print(f"좌표: {boxes.xyxy}")
