# %% [markdown]
# # CLIP Basics
#
# OpenAI CLIP 모델을 사용한 Vision-Language 기초 학습

# %%
import sys
sys.path.insert(0, '../../src')

import torch
from PIL import Image
from transformers import CLIPProcessor, CLIPModel
from cv_pkg.utils import load_image, show_images

# %% [markdown]
# ## 1. 모델 로드

# %%
# CLIP 모델 로드
model = CLIPModel.from_pretrained('openai/clip-vit-base-patch32')
processor = CLIPProcessor.from_pretrained('openai/clip-vit-base-patch32')

# %% [markdown]
# ## 2. Zero-shot Classification

# %%
# 이미지와 텍스트 후보 준비
# image = Image.open('path/to/image.jpg')
# texts = ['a dog', 'a cat', 'a bird']

# inputs = processor(
#     text=texts,
#     images=image,
#     return_tensors='pt',
#     padding=True
# )

# outputs = model(**inputs)
# logits_per_image = outputs.logits_per_image
# probs = logits_per_image.softmax(dim=1)
# print(f"분류 확률: {probs}")

# %% [markdown]
# ## 3. Image-Text Similarity

# %%
# 이미지와 텍스트 간 유사도 계산
# similarity = logits_per_image[0]
# for text, sim in zip(texts, similarity):
#     print(f"{text}: {sim.item():.2f}")
